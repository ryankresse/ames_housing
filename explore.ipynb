# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10, 6)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# There are a fair amount of values, so we'll need to handle that before training a model.

# %%
train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         1
# TotRmsAbvGrd        0
# Functional          2
# Fireplaces          0
# FireplaceQu       730
# GarageType         76
# GarageYrBlt        78
# GarageFinish       78
# GarageCars          1
# GarageArea          1
# GarageQual         78
# GarageCond         78
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1456
# Fence            1169
# MiscFeature      1408
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# dtype: int64

# %% [markdown]
# ## Sale Price

# %% [markdown]
# Our target variable is sales price, so let's look at that first.

# %%
sns.violinplot(train.SalePrice)

# %%
sns.boxplot(train.SalePrice)

# %% [markdown]
# It looks like we have some outliers -- some very expensive houses. As others who have explored this dataset have pointed out, it may help to log transform this variable before fitting a regression model.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# Let's select our numeric variables and write a helper function to help us plot them.

# %%
numeric = train.select_dtypes(exclude=['object']).drop(['MSSubClass', 'Id'], axis=1)

def plotNumericVar(var):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(14, 6))
    mean = numeric[var].mean()
    std = numeric[var].std()
    no_outliers = numeric[numeric[var].apply(lambda x: np.abs(x- mean) /std < 3)]
    
    sns.distplot(numeric[var].dropna(), ax=ax1)
    ax1.set_title('Distribution of {}'.format(var))
    
    sns.regplot(var, 'SalePrice', data=numeric, fit_reg=True, ax=ax2)
    ax2.set_title('{} vs. SalePrice (outliers included)'.format(var))
    sns.regplot(var, 'SalePrice', data=no_outliers, fit_reg=True, ax=ax3)
    ax3.set_title('{} vs. SalePrice (outliers removed)'.format(var))
    plt.tight_layout()

# %% [markdown]
# Let's look at some correlations to get a sense of how our features may relate to each other and to the target variable.

# %%
pearson = numeric.corr(method='pearson')
fig, ax = plt.subplots(1,1, figsize=(10,10))
sns.heatmap(pearson, ax=ax)
ax.set_title('Pearson Correlations')

# %%
spearman = numeric.corr(method='spearman')
fig, ax = plt.subplots(1,1, figsize=(10,10))
sns.heatmap(spearman, ax=ax)
ax.set_title('Spearman Correlations')

# %% [markdown]
# Overall quality seems to be the feature that correlates most strongly with sale price (though, interestingly, overall condition is uncorrelated). Features related to square footage, garage space and the age of the house (year built and remodeled) also correlate show strong, positive correlations.
#
# Let's look more closely at some of those features.

# %%
plotNumericVar('OverallQual')

# %%
plotNumericVar('GrLivArea')

# %%
plotNumericVar('GarageArea')

# %%
plotNumericVar('YearBuilt')

# %% [markdown]
# ## Categorical Variables

# %%
categorical_columns = train.select_dtypes(include=['object']).columns.values
categorical_columns = np.concatenate((categorical_columns,['SalePrice', 'MSSubClass']))
categorical = train[categorical_columns]

# %% [markdown]
# Let's fill missing values before plotting, as missing value may have some relationship with sale price

# %%
categorical = categorical.fillna('None')

# %%
fill_with_none = [
    'Electrical',
    'FireplaceQu',      
    'GarageType',   
    'GarageFinish',     
    'GarageQual',       
    'GarageCond',       
    'PoolQC',          
    'Fence',
    'MiscFeature', 
    'BsmtQual',   
    'BsmtCond',          
    'BsmtExposure',      
    'BsmtFinType1',      
    'BsmtFinType2',
    'MasVnrType',
    'Alley'
]

for col in fill_with_none:
    categorical[col] = categorical[col].fillna('None')

# %% [markdown]
# A helper for plotting.

# %%
def plotCategorical(var):
    fig, (ax1, ax2) = plt.subplots(2,1, figsize=(15,10))
    sns.countplot(categorical[var], ax=ax1)
    ax1.set_title('Counts for {}'.format(var))
    sns.boxplot(var, 'SalePrice', data=categorical,ax=ax2)
    ax2.set_title('{} vs Sale Price'.format(var))

# %% [markdown]
# If you want to see plots for all the variables, you can uncomment and run the code at the bottom of this notebook. But for simplicity, let's just look at a few of the variables I found interesting.
#
# Not surprisingly, features that measured quality seemed to be fairly strongly associated with sale price.

# %%
for col in [col for col in categorical.columns.values if 'Qual' in col]:
    plotCategorical(col)
    plt.show()

# %% [markdown]
# Neigborhood seems to related with price. It's a variable I'd like to explore further.

# %%
plotCategorical('Neighborhood')
plt.show()

# %% [markdown]
# Features related to garage could have some predictive power.

# %%
for col in ['GarageType', 'GarageFinish']:
    plotCategorical(col)
    plt.show()

# %% [markdown]
# ## See more plots

# %% [markdown]
# Uncomment and run the code below to see plots for all the variables.

# %%
'''
for col in numeric.columns:
    plotNumericVar(col)
    plt.tight_layout()
    plt.show()
'''
# Out:
# '\nfor col in numeric.columns:\n    plotNumericVar(col)\n    plt.tight_layout()\n    plt.show()\n'

# %%
'''
for col in [col for col in categorical.columns.values if 'Qual' in col]:
    plotCategorical(col)
    plt.show()
'''
# Out:
# "\nfor col in [col for col in categorical.columns.values if 'Qual' in col]:\n    plotCategorical(col)\n    plt.show()\n"

# %%
categorical.Neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)
